# %% [markdown]
# # A Python Crash Course

# %% [markdown]
# ## How to Use This Notebook
#
# Welcome to your first hands-on Python session! Your instructor will walk through the example cells with you, running each one and explaining what it does. After that, you'll work through the notebook mostly on your own, at your own pace, while the instructor circulates to help.
#
# As you go, watch for these:
#
# - The example cells are already filled in — **run them and read them** to see how each idea works.
# - Wherever you see `# YOUR CODE HERE`, **it's your turn** to write the code.
# - Look for `*Hint:*` notes when you get stuck, and the **Reference Card** at the very end for the key patterns.
#
# You are encouraged to **talk to a neighbor**, compare results, and wave the instructor over whenever you're stuck. Let's dig in!

# %% [markdown]
# ## Teaching Notes: 10-Minute Launch
#
# *(Notes for you, the instructor. Students never see this notebook.)*
#
# This is your students' **first hands-on Python session**, so it works a little differently from the later notebooks. Here the example cells are **already filled in** — your job in the opening ~10 minutes is to **walk through them live**, running each cell and thinking aloud about what it does. Keep this notebook open on a second device (a laptop, tablet, printout, or second monitor) if you'd like the completed practice-cell answers (the `###` markers) handy while you circulate.
#
# **During the launch (~10 minutes),** demonstrate the core ideas by running and narrating these cells:
#
# 1. `print("Hello, world!")` — how a code cell runs, what an error looks like (the missing-parenthesis cell), and how a `#` comment silences a line.
# 2. `2 + 2` — arithmetic operators.
# 3. `x = 5` then `2 + x` — assigning and using a variable.
# 4. `def cel_to_far(celsius): ...` — defining and calling your own function.
# 5. `import math` — bringing in a library.
#
# **Then release the class.** Students run and read the remaining examples and complete the practice cells on their own (`# YOUR CODE HERE`): a comparison, a logic operator, `round()`, a flexible function, and a `for` loop. The worked answers are here (`###`) as your answer key.
#
# **Tip:** do a quick run-through on your own before class — it makes the live walk-through feel easy. Use the **Think About It** prompt to reinforce why cell run-order matters, and point fast finishers to the **Challenge**.

# %% [markdown]
# ## Journey to Jupyter
#
# <center><img src = 'https://upload.wikimedia.org/wikipedia/commons/a/a3/790106-0203_Voyager_58M_to_31M_reduced.gif'><center>

# %% [markdown]
# 1. **Add a new cell below this one but above 2.**

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# 2. **Write a line of code using the `print()` function in the above cell to introduce yourself and run the code using the "play" button.**

# %% [markdown]
# 3. **Copy the cell with the print function and paste it below this cell.**

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# 4. **Run the following code using the `shift` + `enter` shortcut:**

# %%
print("Hello, world!"
# Out:
#   Input In [12]
#     print("Hello, world!"
#                          ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# 5. **Add a hashtag (`#`) to the beginning of the following code:**

# %%
print("Where did I go?")

# %% [markdown]
# ## Python Basics

# %% [markdown]
# ## Operators
#
# Operators are pieces of code that allow us to perform operations. They are at the heart of basic fuctions of the computer.

# %% [markdown]
# ### Arithmetic Operations
#
# | Expression    | Operator |
# | -------- | ------- |
# | Addition  | `+`    |
# | Subtraction | `-`     |
# | Multiplication    | `*`    |
# | Float division  | `/`   |
# | Exponent | `**`     |
# | Remainder    | `%`    |
# | Integer division | `//`     |
# | Order of operations    | `( )`    |
#
# **Try some operators out in the cell below:**

# %%
2+2
# Out:
# 4

# %% [markdown]
# ### Comparison Operators

# %% [markdown]
# Comparison operators, as the name implies is a way to compare two values. This allows you to ask the computer a question.
#
#
# | Name | Operator |
# |-------|-------|
# | equal to | `==` |
# | not equal to | `!=` |
# | greater than | `>` |
# | greater than or equal to | `>=` |
# | less than | `<` |
# | less than or equal to | `<=` |
#
# **See how the computer responds to the following question:**
#
# *Hint: use the `>` operator.*

# %%
# Ask the computer: is 5 greater than 4?
###
5 > 4
###

# %% [markdown]
# ### Logic Operators

# %% [markdown]
# We can combine comparisons using logic operators
#
#
# | Description | Operator |
# |-------|-------|
# | are both statements true? | `and` |
# | is either statement true? | `or` |
#
# **Try them out:**
#
# *Hint: combine two comparisons with `and`.*

# %%
# Use 'and' to check: is 3 less than 4 AND 5 less than 3?
###
3 < 4 and 5 < 3
###

# %% [markdown]
# ## Variables
#
# Like variables in math, variables in coding allow us to assign a value, like `5`,  to a variable, like `x`:

# %%
x = 5

# %%
2 + x
# Out:
# 7

# %% [markdown]
# Variable assignments are not permanent. They can be overwritten by assigning a new value to an existing variable. This is where the order in which you run the cells is important.

# %%
x = 10
2 + x
# Out:
# 12

# %% [markdown]
# #### Think About It
#
# You just saw that `x` was changed from `5` to `10`.
#
# 1. Jupyter runs cells in the order *you* run them, not top to bottom. If you scrolled back up and re-ran an earlier cell that uses `x`, which value would it use now — `5` or `10`?
# 2. Why might running cells out of order cause confusing results?

# %% [markdown]
# However, we should think of variables much more broadly in Python as a "bucket" to store data. That data could be a single number, a list of items, even massive datasets.

# %% [markdown]
# ### Naming Variables

# %% [markdown]
# It is important to give variables a descriptive name as you want to write code so that others can understand it (`x` is too generic).
#
# Variable names are case sensitive. There are several common conventions when there are more than one word in a variable name:
#
# |Convention|Examples|
# |----------|--------|
# |Camel Case|`camelCase`|
# |Snake Case|`snake_case`|
# |Pascal Case|`PascalCase`|
#
# In these notebooks, we will use **snake case**.

# %% [markdown]
# ## Functions

# %% [markdown]
# While operators are the most basic way to interact with a computer, they can be combined to perform more complex tasks. The job of a function is to take one or more inputs, called "arguments", and work on them to "return" an output.
#
# You saw a Python function in the code cell above: `print("Hello, world!")`. This is called the **print function** and it's pretty obvious what it does.

# %% [markdown]
# Fortunately, Python has many built-in functions in addition to `print()`.  They have the general form `function_name(argument_1, argument_2, etc.)`. Here are just a few:
#
# | Function | What it does |
# |-------|-------|
# | `abs(x)` | returns the absolute value of x |
# | `max(x, y, ...)` | returns the largest item from a list |
# | `round(x, ndigits=NONE)` | rounds x to the specified number of decimal places |
#
# Notice the round function takes two arguments `x`, the number you want to round, and `ndigits`, how many decimal places you want to round `x` to. `ndigits=NONE` is the way of showing that the function will defaut to no decimal places if the `ndigits` argument is not specified.

# %% [markdown]
# **Use the `round()` function to round 3.14159 to 2 decimal places:**
#
# *Hint: `round()` takes two arguments — the number, then how many decimal places.*

# %%
# Use round() to round 3.14159 to 2 decimal places
###
round(3.14159, 2)
###

# %% [markdown]
# You can "define" your own functions. See if you can figure out what this function is designed to do:

# %%
def cel_to_far(celsius):
    return (9/5) * celsius + 32

# %% [markdown]
# To use a function we "call" it and "pass" it the necessary argument(s):

# %%
cel_to_far(21.934)
# Out:
# 71.4812

# %% [markdown]
# **Let's try modifying the function so it returns a number rounded to 2 decimal places:**

# %%
def cel_to_far(celsius):
    far = (9/5) * celsius + 32
    return round(far,2)

# %%
cel_to_far(21.934)
# Out:
# 71.48

# %% [markdown]
# **How can improve the function so it is more flexible?**
#
# *Hint: add a second argument (e.g. `dec_places`) and pass it to `round()`.*

# %%
# Define cel_to_far again, adding a second argument for the number of decimal places
###
def cel_to_far(celsius, dec_places):
    far = (9/5) * celsius + 32
    return round(far, dec_places)
###

# %%
cel_to_far(21.934, 1)
# Out:
# 71.5

# %% [markdown]
# ### Libraries
#
# Python has 68 built-in functions. Many more functions are packaged in **libraries**. There are over 100,000 Python libraries!
#
# For example, the `math` library has functions associated with, you guessed it, math operations. Before using it, you must first **import** it:

# %%
import math

# %% [markdown]
# Calling a function from a library uses the following syntax:
#
# `library.function_name(arguments)`
#
# So how do you know what functions are available in a library? After typing `math.`, hit the `tab` key:

# %% [markdown]
# Since we may not know what kind and how many arguments a function takes, we can use `shift` + `tab` to find out:

# %% [markdown]
# **See what functions are in the `math` library and try some out.**

# %%
math.sin(3.14)
# Out:
# 0.0015926529164868282

# %% [markdown]
# ## Loops

# %% [markdown]
# Often, a series of instructions needs to be repeated multiple times. A key part of this is telling the computer when to stop repeating. Sometimes you will want the process repeated a certain *number of times*. Other times, you will want the process repeated *until something happen*.

# %% [markdown]
# A **for loop** will repeat a certain number of times.
#
# *Hint: use `range(0, 3)` and put `print()` inside the loop.*

# %%
# Write a for loop that prints the numbers 0, 1, and 2
###
for y in range(0, 3):
    print(y)
###

# %% [markdown]
# A **while loop** will repeat while a condition is met:

# %%
x = 45
y = 80

while (x < 50 and y < 100):
    x = x + 1
    y = y + 1
    print(x, y)
# Out:
# 46 81
# 47 82
# 48 83
# 49 84
# 50 85

# %% [markdown]
# ## Challenge: Explore on Your Own
#
# Finished early? Try these in the blank cells below. Ask a neighbor or the instructor if you get stuck.
#
# 1. **Reverse it.** Write a function `far_to_cel(fahrenheit)` that converts Fahrenheit back to Celsius.
# 2. **Loop it.** Use a `for` loop to print the first five even numbers.
# 3. **Explore a library.** Import `math` and try `math.sqrt()`, `math.pi`, or `math.factorial()`.

# %%
# Challenge 1: convert Fahrenheit back to Celsius
###
def far_to_cel(fahrenheit):
    return round((fahrenheit - 32) * 5/9, 2)

far_to_cel(71.48)
###

# %%
# Challenge 2 & 3: first five even numbers, then explore the math library
###
for n in range(0, 10, 2):
    print(n)

import math
print(math.sqrt(16), math.pi, math.factorial(5))
###

# %% [markdown]
# ## Reference Card
#
# Stuck? Here are the key patterns from today, all in one place.
#
# **Print something:**
# `print("Hello, world!")`
#
# **Arithmetic:** `+  -  *  /  **  %  //`
#
# **Compare two values** (returns `True`/`False`): `==  !=  >  <  >=  <=`
#
# **Combine comparisons:** `and`, `or`
#
# **Store a value in a variable:**
# `x = 5`
#
# **Define and call a function:**
# ```
# def cel_to_far(celsius):
#     return (9/5) * celsius + 32
#
# cel_to_far(21.9)
# ```
#
# **Round a number:** `round(3.14159, 2)`
#
# **Import and use a library:**
# ```
# import math
# math.sqrt(16)
# ```
#
# **For loop** (repeat a set number of times):
# ```
# for y in range(0, 3):
#     print(y)
# ```
#
# **While loop** (repeat while a condition holds):
# ```
# while x < 50:
#     x = x + 1
# ```
