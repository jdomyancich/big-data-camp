# %% [markdown]
# # A Map to the Stars
#
# <center><img src = 'https://github.com/jdomyancich/big-data-camp/blob/main/imgs/milky_way.jpeg?raw=true' width = 500><center>

# %% [markdown]
# ## How to Use This Notebook
#
# Your instructor got you started — loading the survey data, making a scatter plot, and mapping a patch of the high-redshift sky. Now it's your turn: with your partner, apply the same steps to the medium- and low-redshift samples, at your own pace.
#
# **Start here:** re-create the setup and mapping cells your instructor demonstrated, running each one as you go.
#
# As you go:
# - Wherever you see `# YOUR CODE HERE`, it's your turn to write the code.
# - Check `*Hint:*` notes when you and your partner get stuck, and the **Reference Card** at the end.

# %% [markdown]
# ## Teaching Notes: 10-Minute Launch
#
# *(Notes for you, the instructor. Students never see this notebook.)*
#
# **Set up two screens.** Put the **student notebook** on the projector, and keep **this instructor notebook open on a second device** (a second laptop, a tablet, a printout, or a second monitor) as your private reference. This notebook shows the **completed code** for every demo cell plus a short **"Building it together"** note on what to say. **You don't need to memorize anything** — read the line here and type it into the projected student notebook.
#
# Set the scene first with the story cells (celestial coordinates, right ascension and declination, the Sloan survey) — just a few minutes.
#
# **During the demo (~10 minutes):** type these five cells live into the projected student notebook, talking through your thinking as you go:
#
# 1. `dec_mars` — convert Mars's declination to a single number in degrees.
# 2. Load the data — `import numpy` and read the three redshift datasets with `np.loadtxt`.
# 3. First scatter plot — plot RA vs DEC for the `high_z` galaxies.
# 4. `ra_min / ra_max / dec_min / dec_max` — set the boundaries of the square patch.
# 5. Map the patch — filter `high_z` to those boundaries and plot it in red.
#
# **Then release the class.** Students convert Mars's right ascension themselves, then re-create the map for the **medium** and **low** redshift samples (green and blue) — the same steps you demoed for high redshift. Comparing the three eras shows how the universe has evolved.
#
# **Tip:** do a quick run-through on your own before class — it makes the live typing feel easy.
#
# **As you circulate:** this notebook has the worked solutions for the practice cells (the `###` markers) — your answer key. Use the reflection questions after the maps to draw out how the universe changes across the three redshift ranges, and point fast finishers to the **Extension: Explore!** section.

# %% [markdown]
# Like we use latitude and longitude for locations on Earth, celestial objects are mapped using a similar coordinate system.
#
# For example, Mars has the following coordinates:
#
# **Declination** = +18&deg; 22 minutes 54 seconds<br>
# **Right ascension** = 3 hours 34 minutes 1 seconds

# %% [markdown]
# **Declination**, similar to latitude, is an angular distance of a point north or south of the Celestial Equator, a projection of the Earth's equator into space. Declination is measured in degrees from -90° to +90°
#
# <img src = 'https://upload.wikimedia.org/wikipedia/commons/6/66/Ra_and_dec_demo_animation_small.gif'>
#
# Representing the declination for Mars as a single number in degrees can be done using the following calculation:
#
# **Your instructor works through this one with the class. When you work on your own, you'll write it here yourself.**

# %% [markdown]
# **Building it together**
#
# - Declination is given as degrees + minutes + seconds; we want one number in degrees.
# - There are 60 minutes in a degree and 3600 seconds in a degree.
# - So: `18 + 22/60 + 54/3600`. Save it as `dec_mars` and print to check.

# %%
# Convert the declination of Mars into a single number in degrees
###
dec_mars = 18 + 22/60 + 54/3600
print(dec_mars)
###

# %% [markdown]
# **Right ascension**, similar to longitude, measures an object's relative position to the sun during the vernal equinox. For example, the right ascension of Mars is 3 hours 34 minutes 1 seconds which mean that at the vernal equinox, Mars is 4 hours, 18 minutes and 4 seconds away from reaching the sun's east-west position in the sky.

# %% [markdown]
# **Convert the right ascension of Mars into degrees, store it in a variable called `ra_mars` and print the result.**
#
# *Hint: How many degrees does the Earth rotate in 1 hour?*

# %%
# Convert the right ascension of Mars into degrees, store it as ra_mars, and print it
###
ra_mars = 15*(3 + 34/60 + 1/3600)
print(ra_mars)
###

# %% [markdown]
# ## Let's do some science with this!
#  The data we will be using is from the [Sloan Digital Sky Survey](https://www.sdss.org/) release 16 (DR16).  These data can be queried here: https://skyserver.sdss.org/dr16/en/tools/search/sql.aspx
#
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/6/60/NGC_1273_SDSS.jpg/640px-NGC_1273_SDSS.jpg' width = 600>

# %% [markdown]
# The most common file format for raw data is a `.csv` file, short for "comma separated values".
#
# We have downloaded files giving redshfit, right ascension, declination, and color information for objects in the Sloan Digital Sky Survey classified as galaxies.
#
# **column ids**
# 0:  z (redshift)
# 1:  ra (right ascension)
# 2:  dec (declination)
# 3:  r magnitude   (red)
# 4:  g-r color (redness)
#
# The three datasets span three redshift ranges of  0.08<𝑧<0.12 (`low_z.csv`),  0.4<𝑧<0.5 (`mid_z.csv`) and  0.6<𝑧<0.9 (`high_z.csv`)

# %% [markdown]
# **Read in the three datasets and store each in a separate variable.**
#
# **Your instructor works through this one with the class. When you work on your own, you'll write it here yourself.**

# %% [markdown]
# **Building it together**
#
# - The data lives in three `.csv` files (low, mid, high redshift).
# - `import numpy as np` gives us the tools; `np.loadtxt(url, delimiter=',', skiprows=1)` reads each file, skipping the header row.
# - Save each one in its own variable: `low_z`, `mid_z`, `high_z`.

# %%
# Import numpy and read in the low_z, mid_z, and high_z datasets
###
import numpy as np

low_z = np.loadtxt('https://raw.githubusercontent.com/jdomyancich/big-data-camp/refs/heads/main/data/low_z.csv', delimiter=',', skiprows = 1 )
mid_z = np.loadtxt('https://raw.githubusercontent.com/jdomyancich/big-data-camp/refs/heads/main/data/mid_z.csv', delimiter=',', skiprows = 1 )
high_z = np.loadtxt('https://raw.githubusercontent.com/jdomyancich/big-data-camp/refs/heads/main/data/high_z.csv', delimiter=',', skiprows = 1 )
###

# %% [markdown]
# We can plot the right ascension (x) and declination (y) values for the `high_z` dataset in a scatterplot to visualize the galaxies locations in 2D. Notice how we are calling the columns containing `ra` and `dec`:
#
# **Your instructor works through this one with the class. When you work on your own, you'll write it here yourself.**

# %% [markdown]
# **Building it together**
#
# - Each row is a galaxy; column 1 is RA and column 2 is DEC.
# - `plt.plot(high_z[:,1], high_z[:,2], "b,")` plots every galaxy as a tiny blue dot.
# - Always label your axes, then `plt.show()`.

# %%
# Make a scatter plot of RA (column 1) vs DEC (column 2) for the high_z galaxies
###
import matplotlib.pyplot as plt

plt.plot(high_z[:,1],high_z[:,2], "b,")
plt.xlabel("RA (deg)")
plt.ylabel("DEC (deg)")
plt.show()
###

# %% [markdown]
# To reduce the computational challenge of carrying out our analysis, let us select a subset of these data on a square patch, like we are looking at a smaller patch of the sky.

# %% [markdown]
# <img src = 'https://github.com/jdomyancich/big-data-camp/blob/main/imgs/measuring-sky-with-hand.png?raw=true' width = 400>
#
# Enter values for the right ascension and declination to select a patch of sky with right ascension between 150&deg; and 170&deg; and declination between 40&deg; and 60&deg;.

# %% [markdown]
# **Define the following variables and assign each the appropriate value:**
# * Minimum right ascension: `ra_min`
# * Maximum right ascension: `ra_max`
# * Minimum declination: `dec_min`
# * Maximum declination: `dec_max`
#
# **Your instructor works through this one with the class. When you work on your own, you'll write it here yourself.**

# %% [markdown]
# **Building it together**
#
# - We want a square patch: RA between 150 and 170, DEC between 40 and 60.
# - Store each edge in its own variable so the mapping code can reuse them.
# - `ra_min = 150`, `ra_max = 170`, `dec_min = 40`, `dec_max = 60`.

# %%
# Set the boundaries of the square patch: ra_min, ra_max, dec_min, dec_max
###
ra_min = 150
ra_max = 170
dec_min = 40
dec_max = 60
###

# %% [markdown]
# Now we'll map the galaxies in your selection.
#
# **Your instructor works through this one with the class. When you work on your own, you'll write it here yourself.**

# %% [markdown]
# **Building it together**
#
# - We only want galaxies inside the patch, so we build a True/False mask for RA and for DEC.
# - `np.logical_and` keeps rows where both conditions are true; `np.where` finds their positions.
# - Then plot just those galaxies in red, set a title and equal axes, and `plt.show()`.

# %%
# Map the high_z galaxies that fall inside your selected patch
###
dec_small = np.logical_and(high_z[:,2] > dec_min, high_z[:,2] < dec_max)
ra_small  = np.logical_and(high_z[:,1] > ra_min, high_z[:,1] < ra_max)
combined = np.where(np.logical_and(ra_small, dec_small))
new_map = np.ravel(combined)

plt.plot(high_z[new_map,1],high_z[new_map,2],",r")
plt.title("high redshift sample")
plt.xlabel("RA (deg)")
plt.ylabel("DEC (deg)")
plt.axis("equal")
plt.show()
###

# %% [markdown]
# ## Visualize the Medium and Low Redshift
#
# Now it's your turn. Make scatter plots of the `mid_z` and `low_z` galaxies in the space below. Use green for `mid_z` and blue for `low_z`.

# %% [markdown]
# **Map medium redshift.**
#
# *Hint: copy the high-redshift mapping code and swap `high_z` for `mid_z`, and use green (`"g,"`).*

# %%
# Map the mid_z galaxies (use green)
###
dec_small = np.logical_and(mid_z[:,2] > dec_min, mid_z[:,2] < dec_max)
ra_small  = np.logical_and(mid_z[:,1] > ra_min, mid_z[:,1] < ra_max)
combined = np.where(np.logical_and(ra_small, dec_small))
new_map = np.ravel(combined)

plt.plot(mid_z[new_map,1],mid_z[new_map,2],"g,")
plt.title("mid redshift sample")
plt.xlabel("RA (deg)")
plt.ylabel("DEC (deg)")
plt.axis("equal")
plt.show()
###

# %% [markdown]
# **Map low redshift.**
#
# *Hint: same pattern again with `low_z` and blue (`"b,"`).*

# %%
# Map the low_z galaxies (use blue)
###
dec_small = np.logical_and(low_z[:,2] > dec_min, low_z[:,2] < dec_max)
ra_small  = np.logical_and(low_z[:,1] > ra_min, low_z[:,1] < ra_max)
combined = np.where(np.logical_and(ra_small, dec_small))
new_map = np.ravel(combined)

plt.plot(low_z[new_map,1],low_z[new_map,2],"b,")
plt.title("low redshift sample")
plt.xlabel("RA (deg)")
plt.ylabel("DEC (deg)")
plt.axis("equal")
plt.show()
###

# %% [markdown]
# #### Think About It
#
# Remember, as redshift increases, not only are the galaxies farther away, but our view of them is farther back in time. In other words, we have a way of looking back in time at different periods. The high redshift data shows a younger universe and the low redshift shows an older universe. Therefore, we can see how the universe has evolved!
#
# Looking at the three different periods of the universe:
#
# 1. **What do you see?**
#
# 2. **How has the universe evolved over time?**

# %% [markdown]
# ## Extension: Explore!
#
# Change the part of the sky you want to analyze. Do you see the same pattern? Anything unexpected?

# %%
# Extension: pick a different patch of sky (change ra_min, ra_max, dec_min, dec_max) and re-map
###
ra_min, ra_max, dec_min, dec_max = 180, 200, 20, 40

dec_small = np.logical_and(high_z[:,2] > dec_min, high_z[:,2] < dec_max)
ra_small  = np.logical_and(high_z[:,1] > ra_min, high_z[:,1] < ra_max)
new_map = np.ravel(np.where(np.logical_and(ra_small, dec_small)))

plt.plot(high_z[new_map,1], high_z[new_map,2], "r,")
plt.title("high redshift — new patch")
plt.xlabel("RA (deg)")
plt.ylabel("DEC (deg)")
plt.axis("equal")
plt.show()
###

# %% [markdown]
# ## Reference Card
#
# Stuck? Here are the key patterns from today, all in one place.
#
# **Convert degrees + minutes + seconds to decimal degrees:**
# `dec_mars = 18 + 22/60 + 54/3600`
#
# **Load a CSV into a NumPy array** (skipping the header row):
# `low_z = np.loadtxt(url, delimiter=',', skiprows=1)`
#
# **Scatter plot** (column 1 = RA, column 2 = DEC) as tiny blue dots:
# ```
# plt.plot(data[:,1], data[:,2], "b,")
# plt.xlabel("RA (deg)")
# plt.ylabel("DEC (deg)")
# plt.show()
# ```
#
# **Select a square patch of sky and map it:**
# ```
# dec_small = np.logical_and(data[:,2] > dec_min, data[:,2] < dec_max)
# ra_small  = np.logical_and(data[:,1] > ra_min, data[:,1] < ra_max)
# new_map = np.ravel(np.where(np.logical_and(ra_small, dec_small)))
# plt.plot(data[new_map,1], data[new_map,2], "r,")
# ```
#
# **Plot colors:** `"b,"` blue, `"g,"` green, `"r,"` red (the comma means tiny pixel markers).

# %% [markdown]
# #### Authors: Jeff McMahon, Lindsey Bleem, Alex Drlica-Wagner and John Domyancich
#
# *Dedicated in the memory of Jeff's dad Tim who was always curious, always adventurous, and proud of him no matter what he did.*
